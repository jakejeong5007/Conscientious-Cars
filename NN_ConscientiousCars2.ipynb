# %% [markdown]
# <a href="https://colab.research.google.com/github/jakejeong5007/ConscientiousCars/blob/main/NN_ConscientiousCars2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Conscientious Cars
# Welcome back to CC: ConscientiousCars! Today, we'll be improving on our system for distinguishing dogs from roads, so we can keep these cute puppers safe.

# %%
#@title Run this to load some packages and data! { display-mode: "form" }
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn import model_selection
from sklearn.metrics import accuracy_score
from collections import Counter
import keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D
from keras.layers import Activation, MaxPooling2D, Dropout, Flatten, Reshape
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


def categorical_to_numpy(labels_in):
  labels = []
  for label in labels_in:
    if label == 'dog':
      labels.append(np.array([1, 0]))
    else:
      labels.append(np.array([0, 1]))
  return np.array(labels)


def load_data():
  # Run this cell to download our data into a file called 'cifar_data'
  import gdown
  gdown.download('https://drive.google.com/uc?id=1-BjeqccJdLiBA6PnNinmXSQ6w5BluLem','cifar_data','True'); # dogs v road;

  # now load the data from our cloud computer
  import pickle
  data_dict = pickle.load(open( "cifar_data", "rb" ));
  
  data   = data_dict['data']
  labels = data_dict['labels']
  
  return data, labels

def plot_one_image(data, labels, img_idx):
  from google.colab.patches import cv2_imshow
  import cv2
  import matplotlib.pyplot as plt
  my_img   = data[img_idx, :].squeeze().reshape([32,32,3]).copy()
  my_label = labels[img_idx]
  print('label: %s'%my_label)
  plt.imshow(my_img)
  plt.show()
  
def CNNClassifier(num_epochs=2, layers=1, dropout=0.15):
  def create_model():
    model = Sequential()
    model.add(Reshape((32, 32, 3)))
    
    for i in range(layers):
      model.add(Conv2D(32, (3, 3), padding='same'))
      model.add(Activation('relu'))
    
    model.add(Conv2D(32, (3, 3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(dropout))

    model.add(Conv2D(64, (3, 3), padding='same'))
    model.add(Activation('relu'))
    model.add(Conv2D(64, (3, 3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(dropout))

    model.add(Flatten())
    model.add(Dense(512))
    model.add(Activation('relu'))
    model.add(Dropout(dropout))
    model.add(Dense(2))
    model.add(Activation('softmax'))

    # initiate RMSprop optimizer
    opt = keras.optimizers.RMSprop(lr=0.0001, decay=1e-6)

    # Let's train the model using RMSprop
    model.compile(loss='categorical_crossentropy',
                  optimizer=opt,
                  metrics=['accuracy'])
    return model
  return KerasClassifier(build_fn=create_model, epochs=num_epochs, batch_size=10, verbose=2)

def plot_acc(history, ax = None, xlabel = 'Epoch #'):
    history = history.history
    history.update({'epoch':list(range(len(history['val_accuracy'])))})
    history = pd.DataFrame.from_dict(history)

    best_epoch = history.sort_values(by = 'val_accuracy', ascending = False).iloc[0]['epoch']

    if not ax:
      f, ax = plt.subplots(1,1)
    sns.lineplot(x = 'epoch', y = 'val_accuracy', data = history, label = 'Validation', ax = ax)
    sns.lineplot(x = 'epoch', y = 'accuracy', data = history, label = 'Training', ax = ax)
    ax.axhline(0.5, linestyle = '--',color='red', label = 'Chance')
    ax.axvline(x = best_epoch, linestyle = '--', color = 'green', label = 'Best Epoch')  
    ax.legend(loc = 1)    
    ax.set_ylim([0.4, 1])

    ax.set_xlabel(xlabel)
    ax.set_ylabel('Accuracy (Fraction)')
    
    plt.show()
    
def model_to_string(model):
    import re
    stringlist = []
    model.summary(print_fn=lambda x: stringlist.append(x))
    sms = "\n".join(stringlist)
    sms = re.sub('_\d\d\d','', sms)
    sms = re.sub('_\d\d','', sms)
    sms = re.sub('_\d','', sms)  
    return sms

# %% [markdown]
# ## Exploring CNN parameters.

# %% [markdown]
# Once again, let's load in our dog/road dataset and create our training and test set.

# %%
# load our data
data, labels = load_data()
data = data.astype(float)
labels = categorical_to_numpy(labels)
inputs_train, inputs_test, labels_train, labels_test = model_selection.train_test_split(data, labels, test_size=0.2, random_state=1)

# %% [markdown]
# ## Models for vision: Convolutional Neural Networks

# %% [markdown]
# ###Exercise: Exploring Hyperparameters ✍️
#
# As you know, there is a famous type of neural network known as convolutional neural networks (CNNs). These types of neural networks work particularly well on problems to do with computer vision. Let's try one out!
#
# To load up a simple CNN on scikit-learn, just run:
#
# `cnn = CNNClassifier(num_epochs=E, layers=L, dropout=D)`
#
# Work with your instructors to review what each parameter means and how it affects the model! The dropout represents how many weights we set to 0 during training time, which can help prevent overfitting.
#
# **Try different values of num_epochs, layers, and dropout so that you get the best possible accuracy on the test set using `model.score()`**!

# %%
cnn = CNNClassifier(10, 1, 0.5)
cnn.fit(inputs_train, labels_train)
preds = cnn.predict(inputs_test)
print(cnn.score(inputs_test,labels_test))
# Out:
# Epoch 1/10
# 96/96 - 1s - loss: 10.8722 - accuracy: 0.5781
# Epoch 2/10
# 96/96 - 0s - loss: 2.3475 - accuracy: 0.7219
# Epoch 3/10
# 96/96 - 0s - loss: 1.0462 - accuracy: 0.8031
# Epoch 4/10
# 96/96 - 0s - loss: 0.5224 - accuracy: 0.8625
# Epoch 5/10
# 96/96 - 0s - loss: 0.3941 - accuracy: 0.8750
# Epoch 6/10
# 96/96 - 0s - loss: 0.3993 - accuracy: 0.8698
# Epoch 7/10
# 96/96 - 0s - loss: 0.2577 - accuracy: 0.9042
# Epoch 8/10
# 96/96 - 0s - loss: 0.2542 - accuracy: 0.9115
# Epoch 9/10
# 96/96 - 0s - loss: 0.2354 - accuracy: 0.9229
# Epoch 10/10
# 96/96 - 0s - loss: 0.2651 - accuracy: 0.9198
# 24/24 - 0s
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# 24/24 - 0s - loss: 0.1299 - accuracy: 0.9625
# 0.9624999761581421

# %%
### YOUR CODE HERE

### END CODE

# %% [markdown]
# **How well did your neural network perform?**
#
# CNNs typically perform better than fully-connected neural networks on vision problems, but, as before, they aren't always consistent. They are also sensitive to a number of parameters.

# %% [markdown]
# ## Training and Validation Curves
#
# An important aspect of training neural networks is to prevent overfitting. **How would we recognize overfitting?**
#
# In the first line of code below, we first **fit** the model on the training data and pass in some validation (or test) data to evaluate it. We call it the **history** because we want to retain information about the accuracy at each epoch.
#
# In the second line we plot the history so that we can compare the training and validation accuracies.
#
# ```
# history = model.fit(inputs_train, labels_train, validation_data=(inputs_test, labels_test))
# plot_acc(history)
# ```

# %% [markdown]
# ###Exercise 3 ✍️
#
# Plot a train vs. validation curve for our CNN model.
#
# **After how many epochs does the model begin to overfit? How does this vary as you vary the number of hidden layers and dropout?** Overfitting occurs when the validation accuracy starts to drop below the training accuracy.

# %%
### YOUR CODE HERE
cnn = CNNClassifier(10, 1, 0.5)
cnn.fit(inputs_train, labels_train)
preds = cnn.predict(inputs_test)

history = cnn.fit(inputs_train, labels_train, validation_data=(inputs_test, labels_test))
plot_acc(history)
### END CODE
# Out:
# Epoch 1/10
# 96/96 - 1s - loss: 11.5501 - accuracy: 0.5802
# Epoch 2/10
# 96/96 - 0s - loss: 1.6072 - accuracy: 0.7375
# Epoch 3/10
# 96/96 - 0s - loss: 0.6129 - accuracy: 0.8417
# Epoch 4/10
# 96/96 - 0s - loss: 0.3907 - accuracy: 0.8885
# Epoch 5/10
# 96/96 - 0s - loss: 0.3174 - accuracy: 0.9052
# Epoch 6/10
# 96/96 - 0s - loss: 0.3141 - accuracy: 0.8969
# Epoch 7/10
# 96/96 - 0s - loss: 0.2429 - accuracy: 0.9177
# Epoch 8/10
# 96/96 - 0s - loss: 0.2187 - accuracy: 0.9292
# Epoch 9/10
# 96/96 - 0s - loss: 0.2186 - accuracy: 0.9281
# Epoch 10/10
# 96/96 - 0s - loss: 0.2227 - accuracy: 0.9260
# 24/24 - 0s
# Epoch 1/10
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# 96/96 - 1s - loss: 10.7141 - accuracy: 0.5729 - val_loss: 0.3523 - val_accuracy: 0.8750
# Epoch 2/10
# 96/96 - 0s - loss: 1.9043 - accuracy: 0.7573 - val_loss: 0.1946 - val_accuracy: 0.9208
# Epoch 3/10
# 96/96 - 0s - loss: 1.0685 - accuracy: 0.8115 - val_loss: 0.1586 - val_accuracy: 0.9458
# Epoch 4/10
# 96/96 - 0s - loss: 0.6191 - accuracy: 0.8500 - val_loss: 0.1496 - val_accuracy: 0.9375
# Epoch 5/10
# 96/96 - 0s - loss: 0.3584 - accuracy: 0.8813 - val_loss: 0.1792 - val_accuracy: 0.9250
# Epoch 6/10
# 96/96 - 0s - loss: 0.3372 - accuracy: 0.8948 - val_loss: 0.2035 - val_accuracy: 0.9125
# Epoch 7/10
# 96/96 - 0s - loss: 0.2813 - accuracy: 0.9156 - val_loss: 0.1535 - val_accuracy: 0.9500
# Epoch 8/10
# 96/96 - 0s - loss: 0.2757 - accuracy: 0.9115 - val_loss: 0.1528 - val_accuracy: 0.9542
# Epoch 9/10
# 96/96 - 0s - loss: 0.2384 - accuracy: 0.9146 - val_loss: 0.1381 - val_accuracy: 0.9500
# Epoch 10/10
# 96/96 - 0s - loss: 0.2221 - accuracy: 0.9323 - val_loss: 0.1308 - val_accuracy: 0.9542

# %% [markdown]
# ## Building Neural Networks from Scratch in Keras (Advanced)
#
# So far, we've used helper functions which pre-build Keras neural network models. Now, we will build them on our own!

# %% [markdown]
# Let's walk though how to do this:
#
# **1. Specify model**
#
# ```
# model = Sequential()
# ```
# In this line of code, we build our network where the information flows from LEFT to RIGHT through the network in ONE DIRECTION as opposed to multiple directions. Neurons on the right never pass informations to neurons on the left of it.
#
#
# **2. Add layers to the network**
# ```
# model.add(Dense(4,input_shape = (3,), activation = 'sigmoid'))
# ```
# In this code, we `add` a `layer` of neurons to our network.
#
# This layers consists of 4 neurons. Each neuron is DENSE and connects to all of the previous layer's inputs and all of the subsequent layers outputs. We specify that there are 3 inputs here.
#
# We also specify what kind of output the neuron will give. If you want the neuron to output a number between 0 and 1 (like a probability!) you would use 'softmax' or 'sigmoid'. If you want the neuron to output any number, you can use 'linear'! You'll also often see 'relu', which is when a neuron will only output positive numbers.
#
# ```
# model.add(Dense(1, activation = 'linear'))
# ```
# This code adds ANOTHER layer to the network that has 1 neuron. This one neuron is used to predict a continuous value!
#
# **3. Turn the model on by compiling it**
#
# After having built the network, we want to train and use it, so we have to 'compile' it to prepare. We have to specify at the very least: a loss (how the model measures the quality of its weights), an optimizer (which adjusts the weights), and a metric (how to evaluate our results). Here are some common choices:
# ```
# model.compile(loss='mean_squared_error',
# optimizer = 'adam',
# metrics = ['mean_squared_error'])
#   ```

# %% [markdown]
# Once we've created our network, we can use it very simply! Just like we did with sklearn, we define our input data (x), the true predictions from that data (y), and then train our model with `fit`.
#
# ```
# model.fit(x, y)
# ```

# %% [markdown]
# To use the model, you can use it to predict something with:
# ```
# y = model.predict_classes(x)
# ```
#
# You can actually use the model before you even train it! It just won't perform very well.

# %% [markdown]
# ###Exercise 4 ✍️

# %% [markdown]
# We're going to build this model:
#
# ![](http://cs231n.github.io/assets/nn1/neural_net.jpeg)

# %% [markdown]
# This network can be described as:
# * Input Layer: 3
# * Layer 1 (Hidden): 4 neurons that are activated by `'relu'`
# * Layer 2 (Output): 2 neurons that are activated by `'softmax'`
#
#
# We also want to compile the model with
# `loss = 'categorical_crossentropy'`

# %%
# Fill in the blanks with your group!
### YOUR CODE HERE:
model = Sequential()

model.add(Dense(4,input_shape = (3,), activation = 'relu'))
model.add(Dense(2, activation = 'softmax'))

model.compile(loss='categorical_crossentropy',
optimizer = 'adam',
metrics = ['categorical_crossentropy'])

model.predict_classes([[3,4,2]])
### END CODE
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# array([0])

# %% [markdown]
# ###Exercise 5 ✍️
#
# ![](http://cs231n.github.io/assets/nn1/neural_net2.jpeg)
#
# * Input Layer: 3 Neurons
#
# * Layer 1: 4 neurons that are activated by '`relu' `and take in 3 inputs.
#
# * Layer 2: 4 neurons that are activated by `'relu'`
#
# * Layer 3 (out): 1 neurons that is activated by `'sigmoid'`
#
# Compile the model with
# `loss = 'binary_crossentropy'`

# %%
### YOUR CODE HERE
model = Sequential()

model.add(Dense(4,input_shape = (3,), activation = 'relu'))
model.add(Dense(4, activation = 'relu'))
model.add(Dense(1, activation = 'sigmoid'))

model.compile(loss='binary_crossentropy',
optimizer = 'adam',
metrics = ['binary_crossentropy'])

model.predict_classes([[3,4,2]])
### END CODE
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# array([[1]], dtype=int32)

# %% [markdown]
# ###Exercise 6 ✍️
#
# Now that we know how to build simple neural networks in Keras, let's build a CNN that will perform well on our data set of car and road images.
#
# Below is Keras code for a CNN. It will run as-is on the conscientious cars dataset. However, the performance is suboptimal. Add more layers and change the neural network hyperparameters so that the performance will be better. **Can you get the train and validation accuracy to both be higher than 90%?**
#
# The Keras core layer API may be a useful reference: https://keras.io/layers/core/
#
# In particular and in addition to adding more of the existing convolutional layers and activations, consider using the following layers after a convolution + activation:
#
# `Dropout(N)`
#
# `MaxPooling2D(pool_size=(N, N))`

# %%
##### YOUR CODE HERE

model = Sequential()
model.add(Reshape((32, 32, 3)))

model.add(Conv2D(32, (4, 4), padding='same'))
model.add(Conv2D(32, (4, 4), padding='same'))
model.add(Conv2D(32, (4, 4), padding='same'))
model.add(Conv2D(32, (4, 4), padding='same'))
model.add(Conv2D(32, (4, 4), padding='same'))
model.add(Conv2D(32, (4, 4), padding='same'))
model.add(Conv2D(32, (4, 4), padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(3, 3)))

###
###
model.add(Dense(5, activation = 'relu'))
model.add(Dense(5, activation = 'relu'))
model.add(Dense(5, activation = 'relu'))

###
###

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dense(2))
model.add(Activation('softmax'))

# initiate RMSprop optimizer
opt = keras.optimizers.RMSprop(lr=0.0001, decay=1e-6)

# Let's train the model using RMSprop
model.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

# Train the CNN and plot accuracy.
history = model.fit(inputs_train, labels_train, \
                    validation_data=(inputs_test, labels_test), \
                    epochs=70)
plot_acc(history)
# Out:
# Epoch 1/70
# 30/30 [==============================] - 2s 30ms/step - loss: 1.0736 - accuracy: 0.6080 - val_loss: 0.7191 - val_accuracy: 0.6750
# Epoch 2/70
# 30/30 [==============================] - 0s 15ms/step - loss: 0.5155 - accuracy: 0.7499 - val_loss: 0.9938 - val_accuracy: 0.6125
# Epoch 3/70
# 30/30 [==============================] - 0s 16ms/step - loss: 0.4034 - accuracy: 0.8303 - val_loss: 0.3324 - val_accuracy: 0.8667
# Epoch 4/70
# 30/30 [==============================] - 0s 15ms/step - loss: 0.2625 - accuracy: 0.9041 - val_loss: 0.2697 - val_accuracy: 0.8708
# Epoch 5/70
# 30/30 [==============================] - 0s 16ms/step - loss: 0.2646 - accuracy: 0.9049 - val_loss: 0.1911 - val_accuracy: 0.9208
# Epoch 6/70
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1945 - accuracy: 0.9316 - val_loss: 0.1570 - val_accuracy: 0.9375
# Epoch 7/70
# 30/30 [==============================] - 0s 16ms/step - loss: 0.1564 - accuracy: 0.9392 - val_loss: 0.1882 - val_accuracy: 0.9167
# Epoch 8/70
# 30/30 [==============================] - 0s 16ms/step - loss: 0.1009 - accuracy: 0.9624 - val_loss: 0.3765 - val_accuracy: 0.8708
# Epoch 9/70
# 30/30 [==============================] - 0s 16ms/step - loss: 0.1165 - accuracy: 0.9558 - val_loss: 0.1858 - val_accuracy: 0.9250
# Epoch 10/70
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0710 - accuracy: 0.9740 - val_loss: 0.2346 - val_accuracy: 0.9208
# Epoch 11/70
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0902 - accuracy: 0.9679 - val_loss: 0.1121 - val_accuracy: 0.9542
# Epoch 12/70
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0572 - accuracy: 0.9806 - val_loss: 0.1904 - val_accuracy: 0.9333
# Epoch 13/70
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0492 - accuracy: 0.9789 - val_loss: 0.2837 - val_accuracy: 0.9333
# Epoch 14/70
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0268 - accuracy: 0.9947 - val_loss: 0.2552 - val_accuracy: 0.8958
# Epoch 15/70
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0399 - accuracy: 0.9859 - val_loss: 0.1617 - val_accuracy: 0.9500
# Epoch 16/70
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0268 - accuracy: 0.9926 - val_loss: 0.2437 - val_accuracy: 0.9333
# Epoch 17/70
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0315 - accuracy: 0.9871 - val_loss: 0.2181 - val_accuracy: 0.9542
# Epoch 18/70
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0176 - accuracy: 0.9966 - val_loss: 0.3022 - val_accuracy: 0.9458
# Epoch 19/70
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0059 - accuracy: 0.9997 - val_loss: 0.2561 - val_accuracy: 0.9583
# Epoch 20/70
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0277 - accuracy: 0.9872 - val_loss: 0.2622 - val_accuracy: 0.9625
# Epoch 21/70
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0125 - accuracy: 0.9952 - val_loss: 0.2198 - val_accuracy: 0.9667
# Epoch 22/70
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0073 - accuracy: 0.9985 - val_loss: 0.3198 - val_accuracy: 0.9458
# Epoch 23/70
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0091 - accuracy: 0.9980 - val_loss: 0.2360 - val_accuracy: 0.9708
# Epoch 24/70
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.2659 - val_accuracy: 0.9625
# Epoch 25/70
# 30/30 [==============================] - 0s 15ms/step - loss: 0.2608 - accuracy: 0.9876 - val_loss: 0.2634 - val_accuracy: 0.9500
# Epoch 26/70
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.2975 - val_accuracy: 0.9708
# Epoch 27/70
# 30/30 [==============================] - 0s 16ms/step - loss: 6.7953e-04 - accuracy: 1.0000 - val_loss: 0.3042 - val_accuracy: 0.9542
# Epoch 28/70
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0086 - accuracy: 0.9987 - val_loss: 0.4315 - val_accuracy: 0.9375
# Epoch 29/70
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.3636 - val_accuracy: 0.9458
# Epoch 30/70
# 30/30 [==============================] - 0s 16ms/step - loss: 5.3913e-04 - accuracy: 1.0000 - val_loss: 0.3991 - val_accuracy: 0.9417
# Epoch 31/70
# 30/30 [==============================] - 0s 16ms/step - loss: 1.9607e-04 - accuracy: 1.0000 - val_loss: 0.4280 - val_accuracy: 0.9417
# Epoch 32/70
# 30/30 [==============================] - 0s 16ms/step - loss: 3.8810e-05 - accuracy: 1.0000 - val_loss: 0.4582 - val_accuracy: 0.9500
# Epoch 33/70
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0237 - accuracy: 0.9958 - val_loss: 0.4015 - val_accuracy: 0.9458
# Epoch 34/70
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0030 - accuracy: 0.9989 - val_loss: 0.3815 - val_accuracy: 0.9417
# Epoch 35/70
# 30/30 [==============================] - 0s 16ms/step - loss: 9.0680e-05 - accuracy: 1.0000 - val_loss: 0.3802 - val_accuracy: 0.9500
# Epoch 36/70
# 30/30 [==============================] - 0s 16ms/step - loss: 4.1606e-05 - accuracy: 1.0000 - val_loss: 0.3891 - val_accuracy: 0.9583
# Epoch 37/70
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0020 - accuracy: 0.9992 - val_loss: 0.6264 - val_accuracy: 0.9333
# Epoch 38/70
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0145 - accuracy: 0.9938 - val_loss: 0.6466 - val_accuracy: 0.9333
# Epoch 39/70
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0209 - accuracy: 0.9928 - val_loss: 0.5543 - val_accuracy: 0.9458
# Epoch 40/70
# 30/30 [==============================] - 1s 20ms/step - loss: 4.0331e-04 - accuracy: 1.0000 - val_loss: 0.5391 - val_accuracy: 0.9458
# Epoch 41/70
# 30/30 [==============================] - 0s 16ms/step - loss: 9.5296e-05 - accuracy: 1.0000 - val_loss: 0.5475 - val_accuracy: 0.9458
# Epoch 42/70
# 30/30 [==============================] - 0s 16ms/step - loss: 5.9333e-05 - accuracy: 1.0000 - val_loss: 0.5346 - val_accuracy: 0.9458
# Epoch 43/70
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0036 - accuracy: 0.9989 - val_loss: 0.7152 - val_accuracy: 0.9208
# Epoch 44/70
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0178 - accuracy: 0.9949 - val_loss: 0.4802 - val_accuracy: 0.9417
# Epoch 45/70
# 30/30 [==============================] - 0s 16ms/step - loss: 6.5213e-04 - accuracy: 1.0000 - val_loss: 0.4849 - val_accuracy: 0.9250
# Epoch 46/70
# 30/30 [==============================] - 0s 16ms/step - loss: 4.2205e-05 - accuracy: 1.0000 - val_loss: 0.4866 - val_accuracy: 0.9333
# Epoch 47/70
# 30/30 [==============================] - 0s 16ms/step - loss: 1.7528e-05 - accuracy: 1.0000 - val_loss: 0.5149 - val_accuracy: 0.9458
# Epoch 48/70
# 30/30 [==============================] - 0s 15ms/step - loss: 6.1414e-06 - accuracy: 1.0000 - val_loss: 0.6160 - val_accuracy: 0.9417
# Epoch 49/70
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0074 - accuracy: 0.9980 - val_loss: 0.5304 - val_accuracy: 0.9500
# Epoch 50/70
# 30/30 [==============================] - 0s 16ms/step - loss: 1.1693e-05 - accuracy: 1.0000 - val_loss: 0.5596 - val_accuracy: 0.9458
# Epoch 51/70
# 30/30 [==============================] - 0s 16ms/step - loss: 5.5449e-06 - accuracy: 1.0000 - val_loss: 0.5800 - val_accuracy: 0.9458
# Epoch 52/70
# 30/30 [==============================] - 0s 16ms/step - loss: 2.3497e-06 - accuracy: 1.0000 - val_loss: 0.6147 - val_accuracy: 0.9500
# Epoch 53/70
# 30/30 [==============================] - 0s 16ms/step - loss: 6.0067e-07 - accuracy: 1.0000 - val_loss: 0.6922 - val_accuracy: 0.9542
# Epoch 54/70
# 30/30 [==============================] - 0s 16ms/step - loss: 1.6548e-07 - accuracy: 1.0000 - val_loss: 0.7262 - val_accuracy: 0.9542
# Epoch 55/70
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0119 - accuracy: 0.9974 - val_loss: 0.7674 - val_accuracy: 0.9542
# Epoch 56/70
# 30/30 [==============================] - 0s 16ms/step - loss: 5.0702e-05 - accuracy: 1.0000 - val_loss: 0.7401 - val_accuracy: 0.9583
# Epoch 57/70
# 30/30 [==============================] - 0s 16ms/step - loss: 6.8816e-05 - accuracy: 1.0000 - val_loss: 0.7182 - val_accuracy: 0.9625
# Epoch 58/70
# 30/30 [==============================] - 0s 16ms/step - loss: 1.9243e-06 - accuracy: 1.0000 - val_loss: 0.7293 - val_accuracy: 0.9542
# Epoch 59/70
# 30/30 [==============================] - 0s 16ms/step - loss: 1.3529e-06 - accuracy: 1.0000 - val_loss: 0.7380 - val_accuracy: 0.9625
# Epoch 60/70
# 30/30 [==============================] - 0s 16ms/step - loss: 5.6356e-07 - accuracy: 1.0000 - val_loss: 0.7617 - val_accuracy: 0.9625
# Epoch 61/70
# 30/30 [==============================] - 0s 16ms/step - loss: 1.3610e-07 - accuracy: 1.0000 - val_loss: 0.9055 - val_accuracy: 0.9458
# Epoch 62/70
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0036 - accuracy: 0.9992 - val_loss: 0.7014 - val_accuracy: 0.9500
# Epoch 63/70
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.7216 - val_accuracy: 0.9417
# Epoch 64/70
# 30/30 [==============================] - 0s 16ms/step - loss: 1.6941e-05 - accuracy: 1.0000 - val_loss: 0.6858 - val_accuracy: 0.9458
# Epoch 65/70
# 30/30 [==============================] - 0s 16ms/step - loss: 1.1649e-06 - accuracy: 1.0000 - val_loss: 0.6734 - val_accuracy: 0.9500
# Epoch 66/70
# 30/30 [==============================] - 0s 16ms/step - loss: 9.0208e-07 - accuracy: 1.0000 - val_loss: 0.6790 - val_accuracy: 0.9500
# Epoch 67/70
# 30/30 [==============================] - 0s 16ms/step - loss: 2.6669e-07 - accuracy: 1.0000 - val_loss: 0.7000 - val_accuracy: 0.9500
# Epoch 68/70
# 30/30 [==============================] - 0s 16ms/step - loss: 1.1640e-07 - accuracy: 1.0000 - val_loss: 0.7090 - val_accuracy: 0.9583
# Epoch 69/70
# 30/30 [==============================] - 0s 16ms/step - loss: 4.1823e-08 - accuracy: 1.0000 - val_loss: 0.7546 - val_accuracy: 0.9500
# Epoch 70/70
# 30/30 [==============================] - 0s 16ms/step - loss: 8.6030e-09 - accuracy: 1.0000 - val_loss: 0.7710 - val_accuracy: 0.9583

# %% [markdown]
# Instructor Notes:
#
# Depending on how the students define their model, the validation accuracy may be significantly higher than the training accuracy at some epochs. This can be attributed to (1) the fact that Keras turns off regularization (like dropout) during test time and (2) that Keras reports the validation accuracy at the end of each epoch, but reports the average training accuracy over all the batches in each epoch -- this may be especially significant in the first epoch.
#
# See [Keras FAQ](https://keras.io/getting_started/faq/#why-is-my-training-loss-much-higher-than-my-testing-loss) for more

# %% [markdown]
# **What interesting observations** do you make from the graph? How many epochs should you train for?
#
# We can also print out the structure of our model. What do the parts of the summary mean?

# %%
model.summary()
# Out:
# Model: "sequential_36"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_33 (Reshape)         (None, 32, 32, 3)         0
# _________________________________________________________________
# conv2d_190 (Conv2D)          (None, 32, 32, 32)        1568
# _________________________________________________________________
# conv2d_191 (Conv2D)          (None, 32, 32, 32)        16416
# _________________________________________________________________
# conv2d_192 (Conv2D)          (None, 32, 32, 32)        16416
# _________________________________________________________________
# conv2d_193 (Conv2D)          (None, 32, 32, 32)        16416
# _________________________________________________________________
# conv2d_194 (Conv2D)          (None, 32, 32, 32)        16416
# _________________________________________________________________
# conv2d_195 (Conv2D)          (None, 32, 32, 32)        16416
# _________________________________________________________________
# conv2d_196 (Conv2D)          (None, 32, 32, 32)        16416
# _________________________________________________________________
# activation_228 (Activation)  (None, 32, 32, 32)        0
# _________________________________________________________________
# max_pooling2d_57 (MaxPooling (None, 10, 10, 32)        0
# _________________________________________________________________
# dense_92 (Dense)             (None, 10, 10, 5)         165
# _________________________________________________________________
# dense_93 (Dense)             (None, 10, 10, 5)         30
# _________________________________________________________________
# dense_94 (Dense)             (None, 10, 10, 5)         30
# _________________________________________________________________
# flatten_33 (Flatten)         (None, 500)               0
# _________________________________________________________________
# dense_95 (Dense)             (None, 512)               256512
# _________________________________________________________________
# activation_229 (Activation)  (None, 512)               0
# _________________________________________________________________
# dense_96 (Dense)             (None, 2)                 1026
# _________________________________________________________________
# activation_230 (Activation)  (None, 2)                 0
# =================================================================
# Total params: 357,827
# Trainable params: 357,827
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #Advanced: Cats vs. Dogs
# So far, we've trained a CNN to distinguish between small images of cats and small images of dogs. It's more challenging and time-consuming to train CNNs for bigger images or harder tasks, like distinguishing dogs from cats (which look a lot more like dogs than roads do!)
#
# In this exercise, you'll adapt your previous model to classify large images of dogs vs. cats, and then try implementing a famous CNN architecture. Along the way, you'll deal with some of the debugging that machine learning engineers often have to handle.

# %%
#@title Run this to load cat and dog data. { display-mode: "form" }

#Code here from https://colab.research.google.com/github/google/eng-edu/blob/master/ml/pc/exercises/image_classification_part1.ipynb#scrollTo=4PIP1rkmeAYS

import tensorflow as tf
import os 
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from google.colab.patches import cv2_imshow
import cv2
import matplotlib.pyplot as plt

try:
  road_model = model
  road_saved = True
except NameError:
  road_saved = False

IMG_SHAPE  = 150  # Our training data consists of images with width of 150 pixels and height of 150 pixels
_URL = 'https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip'
zip_dir = tf.keras.utils.get_file('cats_and_dogs_filterted.zip', origin=_URL, extract=True)
base_dir = os.path.join(os.path.dirname(zip_dir), 'cats_and_dogs_filtered')
train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'validation')

train_cats_dir = os.path.join(train_dir, 'cats')  # directory with our training cat pictures
train_dogs_dir = os.path.join(train_dir, 'dogs')  # directory with our training dog pictures
validation_cats_dir = os.path.join(validation_dir, 'cats')  # directory with our validation cat pictures
validation_dogs_dir = os.path.join(validation_dir, 'dogs')  # directory with our validation dog pictures
train_image_generator      = ImageDataGenerator()  # Generator for our training data
validation_image_generator = ImageDataGenerator()  # Generator for our validation data
train_data = train_image_generator.flow_from_directory(batch_size=2000,
                                                           directory=train_dir,
                                                           shuffle=True,
                                                           target_size=(IMG_SHAPE,IMG_SHAPE), #(150,150)
                                                           class_mode='binary').next()
val_data = validation_image_generator.flow_from_directory(batch_size=1000,
                                                              directory=validation_dir,
                                                              shuffle=False,
                                                              target_size=(IMG_SHAPE,IMG_SHAPE), #(150,150)

                                                              class_mode='binary').next()
cd_train_inputs, cd_train_labels = train_data
cd_test_inputs, cd_test_labels = val_data
# Out:
# Found 2000 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.

# %% [markdown]
# **Run the code below to see the dimensions of our training and validation data. What does each number mean? What is different than our previous dataset?**

# %%
print (cd_train_inputs.shape) 
print (cd_train_labels.shape) 
print (cd_test_inputs.shape) 
print (cd_test_labels.shape)
# Out:
# (2000, 150, 150, 3)
# (2000,)
# (1000, 150, 150, 3)
# (1000,)

# %% [markdown]
# **Run this code to see a random image from our training data (different each time).**

# %%
index = np.random.randint(len(cd_train_inputs))
plt.imshow(cd_train_inputs[index]/255)
plt.show()
print("Label:",cd_train_labels[index])
# Out:
# Label: 0.0

# %% [markdown]
# **By adapting code from the previous exercise, build, train, and test a CNN to classify cats vs. dogs.**
# **Hints:**
# *   Use print(model.summary()) for a useful visualization of your model's architecture. Compare the summary of your cat/road and cat/dog classifiers.
# *  Substitute the names of the new datasets.
# *  Get a "first try" working by making small adjustments to a previous model before trying to optimize the accuracy. You can temporarily comment out layers as you figure things out.
# *  The outputs have different shapes betweeen the two datasets. What do you need to change? (You will get an ValueError that suggests how to transform the output to a one-hot encoding.)
# *  If you run out of memory, restart the notebook and/or use your knowledge of convolution arithmetic to reduce the size of an intermediate output (see [Keras documentation](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Conv2D)).
# * Dropout layers help reduce overfitting.

# %%
from keras.utils import to_categorical
model = Sequential()
#TODO: Your code here to build, train, and test a cats vs. dogs CNN!
#If you run into errors, see the hints above for help debugging! 



model.add(Conv2D(32, (4, 4), padding='same'))
model.add(Conv2D(32, (4, 4), padding='same'))
model.add(Conv2D(32, (4, 4), padding='same'))
model.add(Conv2D(32, (4, 4), padding='same'))
model.add(Conv2D(32, (4, 4), padding='same'))
model.add(Conv2D(32, (4, 4), padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(3, 3)))

###
###
model.add(Dense(5, activation = 'relu'))
model.add(Dense(5, activation = 'relu'))
model.add(Dense(5, activation = 'relu'))

###
###

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dense(2))
model.add(Activation('softmax'))

# initiate RMSprop optimizer
opt = keras.optimizers.RMSprop(lr=0.0001, decay=1e-6)

# Let's train the model using RMSprop
model.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

# Train the CNN and plot accuracy.
history = model.fit(cd_train_inputs, to_categorical(cd_train_labels), \
                    validation_data=(cd_test_inputs, to_categorical(cd_test_labels)), \
                    epochs=70)
plot_acc(history)
# Out:
# Epoch 1/70
# 63/63 [==============================] - 5s 58ms/step - loss: 23.6792 - accuracy: 0.5050 - val_loss: 0.7109 - val_accuracy: 0.5140
# Epoch 2/70
# 63/63 [==============================] - 3s 53ms/step - loss: 0.6459 - accuracy: 0.6223 - val_loss: 0.7030 - val_accuracy: 0.5260
# Epoch 3/70
# 63/63 [==============================] - 3s 53ms/step - loss: 0.5939 - accuracy: 0.7115 - val_loss: 0.7025 - val_accuracy: 0.5510
# Epoch 4/70
# 63/63 [==============================] - 3s 53ms/step - loss: 0.4037 - accuracy: 0.8350 - val_loss: 0.8869 - val_accuracy: 0.5690
# Epoch 5/70
# 63/63 [==============================] - 3s 53ms/step - loss: 0.2515 - accuracy: 0.9184 - val_loss: 0.9418 - val_accuracy: 0.5400
# Epoch 6/70
# 63/63 [==============================] - 3s 54ms/step - loss: 0.2065 - accuracy: 0.9321 - val_loss: 1.2128 - val_accuracy: 0.5580
# Epoch 7/70
# 63/63 [==============================] - 3s 54ms/step - loss: 0.1194 - accuracy: 0.9620 - val_loss: 1.8535 - val_accuracy: 0.5370
# Epoch 8/70
# 63/63 [==============================] - 3s 54ms/step - loss: 0.0703 - accuracy: 0.9778 - val_loss: 1.1016 - val_accuracy: 0.5730
# Epoch 9/70
# 63/63 [==============================] - 3s 54ms/step - loss: 0.0450 - accuracy: 0.9921 - val_loss: 1.7405 - val_accuracy: 0.5920
# Epoch 10/70
# 63/63 [==============================] - 3s 54ms/step - loss: 0.0721 - accuracy: 0.9747 - val_loss: 2.0049 - val_accuracy: 0.5900
# Epoch 11/70
# 63/63 [==============================] - 3s 54ms/step - loss: 0.0169 - accuracy: 0.9973 - val_loss: 1.8024 - val_accuracy: 0.5620
# Epoch 12/70
# 63/63 [==============================] - 4s 57ms/step - loss: 0.0280 - accuracy: 0.9934 - val_loss: 2.0048 - val_accuracy: 0.5980
# Epoch 13/70
# 63/63 [==============================] - 3s 53ms/step - loss: 0.0333 - accuracy: 0.9880 - val_loss: 1.9808 - val_accuracy: 0.5580
# Epoch 14/70
# 63/63 [==============================] - 3s 53ms/step - loss: 0.0081 - accuracy: 0.9984 - val_loss: 2.1734 - val_accuracy: 0.5860
# Epoch 15/70
# 63/63 [==============================] - 3s 53ms/step - loss: 0.0184 - accuracy: 0.9950 - val_loss: 2.5417 - val_accuracy: 0.5860
# Epoch 16/70
# 63/63 [==============================] - 3s 53ms/step - loss: 0.0303 - accuracy: 0.9950 - val_loss: 2.3268 - val_accuracy: 0.5790
# Epoch 17/70
# 63/63 [==============================] - 3s 54ms/step - loss: 0.0014 - accuracy: 0.9999 - val_loss: 2.9147 - val_accuracy: 0.5700
# Epoch 18/70
# 63/63 [==============================] - 3s 54ms/step - loss: 0.0086 - accuracy: 0.9965 - val_loss: 2.1311 - val_accuracy: 0.5730
# Epoch 19/70
# 63/63 [==============================] - 3s 53ms/step - loss: 0.0113 - accuracy: 0.9978 - val_loss: 1.5366 - val_accuracy: 0.5800
# Epoch 20/70
# 63/63 [==============================] - 3s 53ms/step - loss: 0.0357 - accuracy: 0.9935 - val_loss: 3.4382 - val_accuracy: 0.5650
# Epoch 21/70
# 63/63 [==============================] - 3s 53ms/step - loss: 0.0129 - accuracy: 0.9963 - val_loss: 2.5800 - val_accuracy: 0.5690
# Epoch 22/70
# 63/63 [==============================] - 3s 53ms/step - loss: 0.0057 - accuracy: 0.9986 - val_loss: 3.3186 - val_accuracy: 0.5790
# Epoch 23/70
# 63/63 [==============================] - 3s 53ms/step - loss: 0.0038 - accuracy: 0.9986 - val_loss: 3.7484 - val_accuracy: 0.5820
# Epoch 24/70
# 63/63 [==============================] - 3s 53ms/step - loss: 0.0153 - accuracy: 0.9950 - val_loss: 3.0207 - val_accuracy: 0.5810
# Epoch 25/70
# 63/63 [==============================] - 3s 53ms/step - loss: 0.0118 - accuracy: 0.9986 - val_loss: 3.0244 - val_accuracy: 0.5700
# Epoch 26/70
# 63/63 [==============================] - 3s 53ms/step - loss: 1.8896e-04 - accuracy: 1.0000 - val_loss: 2.8038 - val_accuracy: 0.5740
# Epoch 27/70
# 63/63 [==============================] - 3s 53ms/step - loss: 0.1193 - accuracy: 0.9860 - val_loss: 2.6640 - val_accuracy: 0.5920
# Epoch 28/70
# 63/63 [==============================] - 3s 53ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 3.3878 - val_accuracy: 0.5740
# Epoch 29/70
# 63/63 [==============================] - 3s 53ms/step - loss: 3.3444e-04 - accuracy: 0.9998 - val_loss: 3.2934 - val_accuracy: 0.5690
# Epoch 30/70
# 63/63 [==============================] - 3s 54ms/step - loss: 6.4849e-04 - accuracy: 1.0000 - val_loss: 3.4058 - val_accuracy: 0.5840
# Epoch 31/70
# 63/63 [==============================] - 3s 53ms/step - loss: 6.4403e-06 - accuracy: 1.0000 - val_loss: 3.8998 - val_accuracy: 0.5900
# Epoch 32/70
# 63/63 [==============================] - 3s 53ms/step - loss: 0.0165 - accuracy: 0.9976 - val_loss: 3.2664 - val_accuracy: 0.5910
# Epoch 33/70
# 63/63 [==============================] - 3s 53ms/step - loss: 8.8882e-05 - accuracy: 1.0000 - val_loss: 3.8298 - val_accuracy: 0.6020
# Epoch 34/70
# 63/63 [==============================] - 3s 53ms/step - loss: 3.8065e-06 - accuracy: 1.0000 - val_loss: 4.0065 - val_accuracy: 0.5950
# Epoch 35/70
# 63/63 [==============================] - 3s 54ms/step - loss: 0.2937 - accuracy: 0.9883 - val_loss: 2.8700 - val_accuracy: 0.5690
# Epoch 36/70
# 63/63 [==============================] - 3s 53ms/step - loss: 8.6823e-04 - accuracy: 1.0000 - val_loss: 3.6693 - val_accuracy: 0.5770
# Epoch 37/70
# 63/63 [==============================] - 3s 53ms/step - loss: 8.2651e-06 - accuracy: 1.0000 - val_loss: 4.3056 - val_accuracy: 0.5820
# Epoch 38/70
# 63/63 [==============================] - 3s 53ms/step - loss: 0.0100 - accuracy: 0.9994 - val_loss: 3.1796 - val_accuracy: 0.5690
# Epoch 39/70
# 63/63 [==============================] - 3s 53ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 4.5775 - val_accuracy: 0.5760
# Epoch 40/70
# 63/63 [==============================] - 3s 53ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 3.9000 - val_accuracy: 0.5850
# Epoch 41/70
# 63/63 [==============================] - 3s 54ms/step - loss: 1.9225e-04 - accuracy: 1.0000 - val_loss: 4.3322 - val_accuracy: 0.5710
# Epoch 42/70
# 63/63 [==============================] - 3s 55ms/step - loss: 0.0153 - accuracy: 0.9967 - val_loss: 4.2822 - val_accuracy: 0.5830
# Epoch 43/70
# 63/63 [==============================] - 3s 53ms/step - loss: 7.2824e-04 - accuracy: 0.9999 - val_loss: 4.4148 - val_accuracy: 0.5730
# Epoch 44/70
# 63/63 [==============================] - 3s 53ms/step - loss: 5.6781e-06 - accuracy: 1.0000 - val_loss: 4.4020 - val_accuracy: 0.5770
# Epoch 45/70
# 63/63 [==============================] - 3s 53ms/step - loss: 9.6549e-07 - accuracy: 1.0000 - val_loss: 4.4996 - val_accuracy: 0.5770
# Epoch 46/70
# 63/63 [==============================] - 3s 53ms/step - loss: 0.0112 - accuracy: 0.9978 - val_loss: 3.9599 - val_accuracy: 0.5900
# Epoch 47/70
# 63/63 [==============================] - 3s 53ms/step - loss: 3.5379e-05 - accuracy: 1.0000 - val_loss: 4.7830 - val_accuracy: 0.5860
# Epoch 48/70
# 63/63 [==============================] - 3s 53ms/step - loss: 7.6113e-07 - accuracy: 1.0000 - val_loss: 4.9196 - val_accuracy: 0.5890
# Epoch 49/70
# 63/63 [==============================] - 3s 53ms/step - loss: 3.9927e-04 - accuracy: 0.9999 - val_loss: 4.2589 - val_accuracy: 0.5810
# Epoch 50/70
# 63/63 [==============================] - 3s 53ms/step - loss: 3.8951e-04 - accuracy: 1.0000 - val_loss: 4.8648 - val_accuracy: 0.5730
# Epoch 51/70
# 63/63 [==============================] - 3s 53ms/step - loss: 6.3406e-07 - accuracy: 1.0000 - val_loss: 5.0276 - val_accuracy: 0.5790
# Epoch 52/70
# 63/63 [==============================] - 3s 53ms/step - loss: 1.2210e-07 - accuracy: 1.0000 - val_loss: 5.0539 - val_accuracy: 0.5830
# Epoch 53/70
# 63/63 [==============================] - 3s 53ms/step - loss: 5.8044e-08 - accuracy: 1.0000 - val_loss: 5.5612 - val_accuracy: 0.5690
# Epoch 54/70
# 63/63 [==============================] - 3s 53ms/step - loss: 0.1492 - accuracy: 0.9823 - val_loss: 4.5865 - val_accuracy: 0.5700
# Epoch 55/70
# 63/63 [==============================] - 3s 53ms/step - loss: 8.7569e-05 - accuracy: 1.0000 - val_loss: 5.3196 - val_accuracy: 0.5690
# Epoch 56/70
# 63/63 [==============================] - 3s 53ms/step - loss: 1.0659e-07 - accuracy: 1.0000 - val_loss: 5.3252 - val_accuracy: 0.5750
# Epoch 57/70
# 63/63 [==============================] - 3s 53ms/step - loss: 3.3731e-08 - accuracy: 1.0000 - val_loss: 5.9839 - val_accuracy: 0.5790
# Epoch 58/70
# 63/63 [==============================] - 3s 53ms/step - loss: 0.0476 - accuracy: 0.9936 - val_loss: 4.3962 - val_accuracy: 0.5720
# Epoch 59/70
# 63/63 [==============================] - 3s 53ms/step - loss: 1.7625e-04 - accuracy: 1.0000 - val_loss: 4.8527 - val_accuracy: 0.5680
# Epoch 60/70
# 63/63 [==============================] - 3s 53ms/step - loss: 7.5957e-07 - accuracy: 1.0000 - val_loss: 5.3502 - val_accuracy: 0.5720
# Epoch 61/70
# 63/63 [==============================] - 3s 53ms/step - loss: 3.3595e-08 - accuracy: 1.0000 - val_loss: 6.0757 - val_accuracy: 0.5810
# Epoch 62/70
# 63/63 [==============================] - 3s 53ms/step - loss: 0.0174 - accuracy: 0.9968 - val_loss: 4.7686 - val_accuracy: 0.5720
# Epoch 63/70
# 63/63 [==============================] - 3s 53ms/step - loss: 1.4540e-05 - accuracy: 1.0000 - val_loss: 5.4305 - val_accuracy: 0.5710
# Epoch 64/70
# 63/63 [==============================] - 3s 53ms/step - loss: 1.7437e-07 - accuracy: 1.0000 - val_loss: 6.0473 - val_accuracy: 0.5690
# Epoch 65/70
# 63/63 [==============================] - 3s 53ms/step - loss: 3.3099e-08 - accuracy: 1.0000 - val_loss: 5.9834 - val_accuracy: 0.5790
# Epoch 66/70
# 63/63 [==============================] - 3s 53ms/step - loss: 0.0222 - accuracy: 0.9984 - val_loss: 3.2704 - val_accuracy: 0.5800
# Epoch 67/70
# 63/63 [==============================] - 3s 53ms/step - loss: 0.0089 - accuracy: 0.9995 - val_loss: 3.5988 - val_accuracy: 0.5830
# Epoch 68/70
# 63/63 [==============================] - 3s 53ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 6.8373 - val_accuracy: 0.5930
# Epoch 69/70
# 63/63 [==============================] - 3s 53ms/step - loss: 2.3489e-05 - accuracy: 1.0000 - val_loss: 5.8886 - val_accuracy: 0.5740
# Epoch 70/70
# 63/63 [==============================] - 3s 54ms/step - loss: 4.2768e-08 - accuracy: 1.0000 - val_loss: 5.9349 - val_accuracy: 0.5730

# %% [markdown]
# ##Advanced Challenge: Implementing a Famous Architecture for Cats vs. Dogs
#
# Having trouble designing an effective architecture? Try implementing a version of AlexNet, one of the most famous CNNs for image convolution ever. You can find this image and other useful information on this network [here](https://towardsdatascience.com/the-w3h-of-alexnet-vggnet-resnet-and-inception-7baaaecccc96).
#
# ![](https://miro.medium.com/max/1400/1*bD_DMBtKwveuzIkQTwjKQQ.png)
# How do we read this diagram?
#
# On the left side, we start with images of dimension 224x224x3 (RGB). We apply a filter composed of 96 kernels of size 11x11, with stride size 4. We end up with data of dimension 55x55x96. We pass through multiple layers of convolution and max pooling as shown, before ending with three dense (fully connected) layers.
#
# Not shown: each layer uses ReLU activation, and we include dropout before the first two dense layers. Make sure to include those!
#
# You'll want to adjust some of these dimensions, for a few reasons: we're starting with 150x150 rather than 224x224 images, ending with 2 labels rather than 1000, and have limited data and memory. Use your knowledge of convolution arithmetic (see CNN slides) and the [Keras documentation](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Conv2D) to change the stride, kernel, and/or padding.
#
# Use model.summary() to understand the dimensions of your data at each step. To speed things up as you're building, you can set the number of epochs to 1.

# %%
model = Sequential()
#TODO: Your code to run, train, and test AlexNet here:

# %% [markdown]
# You might find that even AlexNet isn't working that well for you!
#
# This is because having a good architecture is only half the battle: AlexNet is a complex model designed to learn from millions of images. We're using a small dataset of only 2000 training images, so it's not surprising that our results aren't great. Our model is overfitting: essentially memorizing the few training images, rather than really learning the difference between a cat and a dog. (The advantage is that our model trains quickly.)
#
# To get really good performance, we need more data. If we can't find more, we could use *data augmentation*: inventing new training data by transforming our existing images. You can read more about it at https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html.

# %% [markdown]
# ![](https://images.pexels.com/photos/316/black-and-white-animal-dog-pet.jpg?auto=compress&cs=tinysrgb&dpr=2&h=650&w=940)
